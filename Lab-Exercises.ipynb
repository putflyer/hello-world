# %% [markdown]
# # Lab Exercises
#
# ## Introduction to Python, Part 3
#
# ### Questions/Office Hours
#
# If you have questions about this week's lab **ANY** TA for this class can help you with any problems in office hours. That being said, if you need help over email it is best to email **YOUR** TA.
#
# You can also always ask the instructor for help with skills labs (even though they are not covered in lecture). You can email the instructor of come to his office hours.

# %% [markdown]
# ----

# %% [markdown]
# ## Exercises
#
# The exercises this week deal with some features that we haven't otherwise covered. There are links to specific parts of the Python for Everyone book in each question, but here's a more general reference:
#
# * [Chapter 7: Files](https://www.py4e.com/html3/07-files)
# * [Chapter 8: Lists](https://www.py4e.com/html3/08-lists)
# * [Chapter 9: Dictionaries](https://www.py4e.com/html3/09-dictionaries)
#
# ### A Note on Boilerplate
#
# One of the major benefits of tools like Jupyter are that it makes it easy to strip away the "boilerplate" that comes with programming languages; some of these exercises relies on a little bit more of that than in weeks past. If you get confused or something stops working, email your TA or come to ofice hours.

# %% [markdown]
# ----

# %% [markdown]
# #### **Exercise 1**
#
# ###### sections to reference: [opening files](https://www.py4e.com/html3/07-files)
#
# This one definitely falls in the category of "pointless exercises". You're going to make a program that prompts for a filename. If the file exists, quit the program! Don't print anything out, don't do anything with the file, don't do anything. Just quit. If the file *doesn't* exist, complain, and prompt the user for a filename again. Do this until the user gives you a valid filename or pours water on their computer in frustration. (Just kidding. Don't pour water on your computer.)
#
# You're going to want to put the filename prompt inside a loop, so you can ask the user for a filename as many times as you want. But what kind of loop? And how will you get out of the loop once you've got a valid file?
#
# ![thinking face](https://media.giphy.com/media/3o7buirYcmV5nSwIRW/giphy.gif)

# %%
check = 1
while check == 1:
    f_name = input("What is the name of your value?")
    
    try:
        open(f_name)
    except:
        print("Please try again.")
    else:
        check += 1
# Out:
# What is the name of your value? richard3.txt

# %% [markdown]
# #### **Exercise 2**
#
# ###### sections to reference: [opening files](https://www.py4e.com/html3/07-files)
#
# Write a program that asks the user for a file and simply prints the entire contents of the file out. If the user enters a file that doesn't exist, give the user an error and prompt for a filename again.
#
# **Hint**: You can do the printing in *one line of code*.

# %%
check = 1
while check == 1:
    f_name = input("What is the name of your value?")
    
    try:
        myfile = open(f_name)
    except:
        print("Please try again.")
    else:
        check += 1

for line in myfile:
    print(line)

myfile.close()
# Out:
# What is the name of your value? richard3.txt
# Now is the winter of our discontent
#
# Made glorious summer by this sun of York
#
# And all the clouds that lour'd upon our house
#
# In the deep bosom of the ocean buried
#
# Now are our brows bound with victorious wreaths
#
# Our bruised arms hung up for monuments
#
# Our stern alarums changed to merry meetings
#
# Our dreadful marches to delightful measures
#
# Grim visaged war hath smooth'd his wrinkled front
#
# And now instead of mounting barded steeds
#
# To fright the souls of fearful adversaries
#
# He capers nimbly in a lady's chamber
#
# To the lascivious pleasing of a lute
#
# But I that am not shaped for sportive tricks
#
# Nor made to court an amorous looking glass
#
# I that am rudely stamp'd and want love's majesty
#
# To strut before a wanton ambling nymph
#
# I that am curtail'd of this fair proportion
#
# Cheated of feature by dissembling nature
#
# Deformed unfinish'd sent before my time
#
# Into this breathing world scarce half made up
#
# And that so lamely and unfashionable
#
# That dogs bark at me as I halt by them
#
# Why I in this weak piping time of peace
#
# Have no delight to pass away the time
#
# Unless to spy my shadow in the sun
#
# And descant on mine own deformity
#
# And therefore since I cannot prove a lover
#
# To entertain these fair well spoken days
#
# I am determined to prove a villain
#
# And hate the idle pleasures of these days
#
# Plots have I laid inductions dangerous
#
# By drunken prophecies libels and dreams
#
# To set my brother Clarence and the king
#
# In deadly hate the one against the other
#
# And if King Edward be as true and just
#
# As I am subtle false and treacherous
#
# This day should Clarence closely be mew'd up
#
# About a prophecy which says that G
#
# Of Edward's heirs the murderer shall be
#
# Dive thoughts down to my soul here
#
# Clarence comes

# %% [markdown]
# #### **Exercise 3**
#
# ###### sections to reference: [parsing strings](https://www.py4e.com/html3/06-strings)
#
# This exercise deals with a test file, `spam1.txt`. You can open that file in a new tab so you can get a sense for what it looks like and what you're going to be dealing with.
#
# You're going to be writing a program that deals with a list of spam confidence values. The file, spam1.txt, looks something like this:

# %% [raw]
# X-DSPAM-Confidence: 0.8475
# X-DSPAM-Confidence: 0.9288
# X-DSPAM-Confidence: 0.0129
# X-DSPAM-Confidence: 0.5102
# X-DSPAM-Confidence: 0.8912
# ...

# %% [markdown]
# There are 500 spam confidence values in the file `spam1.txt`. I want you to tell me two things about the values:
#
# 1. The **average** of all of the spam values in the file, and
# 1. **How many** emails have a spam value of over 95% (so, >0.95).
#
# You'll need to read the file line by line and process each line so you can get the float.
#
# After you're done with that program, make a Markdown cell below your code and **tell me**, in a few sentences, what the average spam confidence *means*. By way of explanation, the spam value is a value generated by an algorithm (individual email providers keep their algorithms closely guarded, but they're all pretty much based on *Bayesian math*, if you're interested.) That algorithm rates any given email from 0 to 1 on how confident they are that the email is spam. 1 means that the algorithm thinks it *definitely* is spam, and 0 means that the algorithm thinks there's no chance it's spam.
#
# So, once you have your average value, **what does that mean** for any given email in the set? What are the chances it'll be spam or not?

# %%
myfile = open("spam1.txt")
sum = 0
count = 0
for line in myfile:
    thing = line[20:]
    temp = float(thing)
    sum += temp
    if temp >= 0.95:
        count += 1
average = sum/500
print(average)
print(count)
myfile.close()
# Out:
# 0.7507991999999993
# 68

# %% [markdown]
# The average spam confidence means that over the course of 500 emails the confidence that the counclusion about whether the email is spam is about 75%. That means that on any given email the confidence that the correct conclusion on the spaw was given is 3/4s of a chance.

# %% [markdown]
# #### **Exercise 4**
#
# ###### sections to reference: [searching through a file](https://www.py4e.com/html3/07-files)
#
# This exercise is a continuation of the previous one. You've got a new text file to process, called `spam2.txt`. It has a bunch of spam confidence values, but it's also got some other information, too, like the sender, message subject, and the date and time that it's been sent. A sample record from the file looks like this:

# %% [raw]
# From louis@media.berkeley.edu Fri Jan 4 18:10:48 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# X-Sieve: CMU Sieve 2.3
# Message-ID: <200801042308.m04N8v6O008125@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# Content-Transfer-Encoding: 7bit
# Date: Fri 4 Jan 2008 18:08:57 -0500
# To: source@collab.sakaiproject.org
# Subject: [sakai] svn commit: r39771 - in bspace/site-manage/sakai_2-4-x/site-manage-tool/tool/src: bundle java/org/sakaiproject/site/tool
# X-Content-Type-Outer-Envelope: text/plain; charset=UTF-8
# X-Content-Type-Message-Body: text/plain; charset=UTF-8
# Content-Type: text/plain; charset=UTF-8
# X-DSPAM-Result: Innocent
# X-DSPAM-Processed: Fri Jan  4 18:10:48 2008
# X-DSPAM-Confidence: 0.6178
# X-DSPAM-Probability: 0.0000

# %% [markdown]
# There is a lot of information here, and this, if you can believe it, is a *stripped-down* version of what the email server records look like.
#
# `spam2.txt` contains a bunch of email records. You're going to write a program, similar to Exercise 3, wherein you grab the spam confidence from each email. Like before, you're going to **take the average** of these values. When you encounter an email with a spam confidence greater than 95%, though, you're going to **print out** the email address that sent the email, the email address that received it, the date and time that it was sent, and the spam confidence value.
#
# **Note**: Don't simply print out the entire lines of the file that have that information; get the specific items that you want and format it nicely.

# %%
myfile = open('spam2.txt')
count = 0
storehouse = 0
for line in myfile:
    line = line.rstrip()
    count += 1
    if line.startswith('To:'):
        receiver = line[3:]
    if line.startswith('Date:'):
        date = line[6:31]
    if line.startswith('X-DSPAM-Confidence:'):
        thing = line[20:]
        temp = float(thing)
    if line.startswith('Author:'):
        author = line[8:]
        if temp > 0.95:
            print()
            print('We are very cofident in our ananlysis of this email. The confidence is: ' + thing)
            print('The author of this email is: ' + author)
            print('The receiver of this emai is: ' + receiver)
            print('The date and time this email was sent is: ' + date)
# Out:
# We are very cofident in our ananlysis of this email. The confidence is: 0.9846
# The author of this email is: cwen@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 16:33:03
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9907
# The author of this email is: cwen@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 16:22:15
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9895
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 15:25:57
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9965
# The author of this email is: cwen@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 15:24:11
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9875
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 15:22:15
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9867
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 14:30:46
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9903
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 13:49:37
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9907
# The author of this email is: cwen@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 13:19:10
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9886
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 13:15:37
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9875
# The author of this email is: cwen@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 13:06:42
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9854
# The author of this email is: cwen@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 13:04:47
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9877
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 12:30:40
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9881
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 12:26:30
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9864
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 12:23:18
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9870
# The author of this email is: cwen@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 11:43:01
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9837
# The author of this email is: gopal.ramasammycook@gmail.com
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 11:10:46
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9852
# The author of this email is: gsilver@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 10:26:43
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9928
# The author of this email is: stuart.freeman@et.gatech.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 10:21:33
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9898
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 10:19:54
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9855
# The author of this email is: gsilver@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 10:06:12
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9856
# The author of this email is: gsilver@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 10:03:38
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9892
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 10:01:01
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9879
# The author of this email is: wagnermr@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 09:12:14
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9843
# The author of this email is: gopal.ramasammycook@gmail.com
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 3 Jan 2008 08:42:40
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9871
# The author of this email is: wagnermr@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 17:01:05
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9947
# The author of this email is: stuart.freeman@et.gatech.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 16:52:23
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9832
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 15:50:13
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9864
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 15:18:59
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9842
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 14:34:07
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9860
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 11:12:00
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9842
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 11:08:05
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9865
# The author of this email is: david.horwitz@uct.ac.za
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 09:39:09
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9865
# The author of this email is: aaronz@vt.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 09:10:36
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9852
# The author of this email is: david.horwitz@uct.ac.za
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 09:06:18
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9856
# The author of this email is: david.horwitz@uct.ac.za
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 08:53:30
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9843
# The author of this email is: gopal.ramasammycook@gmail.com
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 06:59:39
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9844
# The author of this email is: david.horwitz@uct.ac.za
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 03:02:55
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9823
# The author of this email is: david.horwitz@uct.ac.za
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Wed, 2 Jan 2008 02:51:47
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9872
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Mon, 31 Dec 2007 16:27:25
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9897
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Mon, 31 Dec 2007 14:55:49
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9887
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Mon, 31 Dec 2007 14:51:25
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.
umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 12:18:14
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9795
# The author of this email is: jzaremba@unicon.net
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 11:13:06
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9850
# The author of this email is: aaronz@vt.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 10:21:22
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9859
# The author of this email is: dlhaines@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 10:13:55
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9846
# The author of this email is: dlhaines@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 10:11:46
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9863
# The author of this email is: dlhaines@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 10:06:30
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9803
# The author of this email is: ajpoland@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 09:22:36
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9912
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 09:21:20
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9896
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 09:20:25
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9907
# The author of this email is: rjlowe@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 09:16:38
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9860
# The author of this email is: dlhaines@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 08:58:14
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9799
# The author of this email is: aaronz@vt.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 05:58:26
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9807
# The author of this email is: ktsao@stanford.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Fri, 19 Oct 2007 01:57:39
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9837
# The author of this email is: ian@caret.cam.ac.uk
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 18:41:12
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9862
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 16:06:59
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9872
# The author of this email is: zqian@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 15:58:51
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9830
# The author of this email is: aaronz@vt.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 13:12:28
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9769
# The author of this email is: jzaremba@unicon.net
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 12:15:19
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9826
# The author of this email is: dlhaines@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 12:05:48
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9861
# The author of this email is: chmaurer@iupui.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 11:49:30
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9810
# The author of this email is: zach.thomas@txstate.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 11:31:49
#
# We are very cofident in our ananlysis of this email. The confidence is: 0.9836
# The author of this email is: dlhaines@umich.edu
# The receiver of this emai is:  source@collab.sakaiproject.org
# The date and time this email was sent is: Thu, 18 Oct 2007 10:53:54

# %% [markdown]
# #### **Exercise 5**
#
# ###### sections to reference: [list methods](https://www.py4e.com/html3/08-lists)
#
# Below are the lines of a program I wrote to add some things to a list of my favorite foods, sort the list, and then print them out in alphabetical order. The problem is that, when I was uploading this program to the supercomputer, my internet stopped working and my program's lines got all mixed up.
#
# Your task is this: rearrange the lines below so the program sorts and then prints the elements in my list of foods. When you've got the order all sorted out, put it in the code cell below. And thanks for your help!
#
# ```python
# my_fave_foods.sort()
# for food in my_fave_foods:
# my_fave_foods.append("asiago cheese")
# my_fave_foods = ["serrano peppers", "bananas", "apple pie", "veal", "smoked brisket"]
#     print(food)
# ```

# %%
my_fave_foods = ["serrano peppers", "bananas", "apple pie", "veal", "smoked brisket"]
my_fave_foods.append("asiago cheese")
my_fave_foods.sort()
for food in my_fave_foods:
    print(food)
# Out:
# apple pie
# asiago cheese
# bananas
# serrano peppers
# smoked brisket
# veal

# %% [markdown]
# #### **Exercise 6**
#
# ###### sections to reference: [lists](https://www.py4e.com/html3/08-lists)
#
# So, now that you're an expert in sorting lists of food, let's get a little bit more literary. `richard3.txt` contains the text of Richard's opening soliloquy from Shakespeare's play *Richard III*.
#
# You can watch a performance of it [here](https://www.youtube.com/watch?v=OfaVYn1v4jM), if you're interested.
#
# You're going to write a program that reads in the soliloquy from the file line by line. Then, using the `split` function, split each line into a list of words. Create a list to contain all of your words. Going word by word, check if the word is already in the list. If not, add it.
#
# Once you've gone through the whole file, sort the list of words in alphabetical order, and print it out.

# %%
myfile = open('richard3.txt')
list_of_words = []

for line in myfile:
    test = 0
    temp_line = line.split()
    for things in temp_line:
        count = 0
        for words in list_of_words:
            if things == list_of_words[count]:
                test += 1
            count += 1
        if test == 0:
            list_of_words.append(things)
list_of_words.sort()
for word in list_of_words:
    print(word)
# Out:
# About
# And
# As
# But
# By
# Cheated
# Clarence
# Deformed
# Dive
# Edward's
# Grim
# Have
# He
# I
# In
# Into
# Made
# Nor
# Now
# Of
# Our
# Plots
# That
# This
# To
# Unless
# Why
# a
# all
# am
# amorous
# an
# and
# arms
# as
# at
# bark
# be
# before
# bruised
# by
# capers
# chamber
# closely
# court
# day
# delight
# discontent
# dogs
# down
# dreams
# drunken
# for
# fright
# front
# glass
# glorious
# hath
# have
# heirs
# his
# hung
# in
# is
# lady's
# libels
# looking
# made
# me
# mew'd
# monuments
# my
# nimbly
# no
# not
# of
# our
# prophecies
# sent
# shaped
# should
# smooth'd
# summer
# sun
# that
# the
# this
# thoughts
# time
# to
# unfinish'd
# up
# visaged
# war
# winter
# wrinkled

# %% [markdown]
# #### **Exercise 7**
#
# ###### sections to reference: [dictionaries and files](https://www.py4e.com/html3/09-dictionaries)
#
# In the previous exercise, you just discarded words that were duplicates, but what if you wanted to count them?
#
# You're going to read in `richard3.txt` again, but this time use a *dictionary*. Iterate through the lines in the file and, for each word, if this is its first occurence, add the word as a *key* to the dictionary and the number "1" as a *value*. If the word exists in the dictionary, *add one* to its value.
#
# Then, print out your word-frequency dictionary.

# %%
myfile = open('richard3.txt')
list_of_words = []

dictionary = dict()


for line in myfile:
    test = 0
    temp_line = line.split()
    for things in temp_line:
        count = 0
        for words in list_of_words:
            if things == list_of_words[count]:
                test += 1
                dictionary[things] += 1
            count += 1
        if test == 0:
            list_of_words.append(things)
            dictionary[things] = 1
list_of_words.sort()
print(dictionary)
# Out:
# {'Now': 2, 'is': 1, 'the': 13, 'winter': 1, 'of': 10, 'our': 3, 'discontent': 1, 'Made': 1, 'glorious': 1, 'summer': 1, 'by': 3, 'this': 4, 'sun': 2, 'And': 7, 'all': 1, 'In': 2, 'Our': 3, 'bruised': 1, 'arms': 1, 'hung': 1, 'up': 3, 'for': 2, 'monuments': 1, 'Grim': 1, 'visaged': 1, 'war': 1, 'hath': 1, "smooth'd": 1, 'his': 1, 'wrinkled': 1, 'front': 1, 'To': 5, 'fright': 1, 'He': 1, 'capers': 1, 'nimbly': 1, 'in': 3, 'a': 6, "lady's": 1, 'chamber': 1, 'But': 1, 'I': 9, 'that': 5, 'am': 5, 'not': 1, 'shaped': 1, 'Nor': 1, 'made': 2, 'to': 5, 'court': 1, 'an': 1, 'amorous': 1, 'looking': 1, 'glass': 1, 'Cheated': 1, 'Deformed': 1, "unfinish'd": 1, 'sent': 1, 'before': 1, 'my': 4, 'time': 3, 'Into': 1, 'That': 1, 'dogs': 1, 'bark': 1, 'at': 1, 'me': 1, 'as': 2, 'Why': 1, 'Have': 1, 'no': 1, 'delight': 1, 'Unless': 1, 'Plots': 1, 'have': 1, 'By': 1, 'drunken': 1, 'prophecies': 1, 'libels': 1, 'and': 4, 'dreams': 1, 'As': 1, 'This': 1, 'day': 1, 'should': 1, 'Clarence': 2, 'closely': 1, 'be': 2, "mew'd": 1, 'About': 1, 'Of': 1, "Edward's": 1, 'heirs': 1, 'Dive': 1, 'thoughts': 1, 'down': 1}
